# %% [markdown]
# <a href="https://colab.research.google.com/github/ihwala/Hello/blob/main/Workshop5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define x range
x = np.linspace(-5, 5, 200)

# Equations:
# 1) 2x + 3y = 3 → y = (3 - 2x)/3
y1 = (3 - 2*x) / 3

# 2) 4x + 6y = 6 → y = (6 - 4x)/6
y2 = (6 - 4*x) / 6

# 3) 3x - 2y = 1 → y = (3*x - 1)/2
y3 = (3*x - 1) / 2

# Solve intersection of eqn (1) and (3)
A = np.array([[2, 3],
              [3, -2]])
b = np.array([3, 1])
intersection = np.linalg.solve(A, b)

# Plotting
fig, ax = plt.subplots(figsize=(6,6))

ax.plot(x, y1, 'r', label='2x + 3y = 3')
ax.plot(x, y2, 'g', label='4x + 6y = 6')
ax.plot(x, y3, 'b', label='3x - 2y = 1')

# Mark intersection point
ax.scatter(intersection[0], intersection[1], color='black', s=60, zorder=5)
ax.text(intersection[0]+0.2, intersection[1], f"({intersection[0]:.2f}, {intersection[1]:.2f})", color='black')

# Axes setup
ax.axhline(0, color='k', linewidth=1)
ax.axvline(0, color='k', linewidth=1)
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_aspect('equal')
ax.grid(True, ls=':')

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

print("Intersection point of eqn (1) and (3):", intersection)
# Out:
# Intersection point of eqn (1) and (3): [0.69230769 0.53846154]

# %%
import numpy as np

A = np.random.randint(1, 10, (5,6))
B = np.random.randint(1, 10, (5,6))

C = A + B

print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("Result (A+B):\n", C)
# Out:
# Matrix A:
#  [[9 2 4 6 3 9]
#  [2 1 6 3 1 3]
#  [7 5 7 4 9 1]
#  [6 2 1 7 2 1]
#  [1 3 7 2 1 9]]
# Matrix B:
#  [[5 3 2 8 5 9]
#  [2 2 4 1 7 8]
#  [5 3 7 1 8 4]
#  [7 7 8 4 7 8]
#  [6 5 4 9 4 3]]
# Result (A+B):
#  [[14  5  6 14  8 18]
#  [ 4  3 10  4  8 11]
#  [12  8 14  5 17  5]
#  [13  9  9 11  9  9]
#  [ 7  8 11 11  5 12]]

# %%
import numpy as np

A = np.random.randint(1, 10, (5,6))
B = np.random.randint(1, 10, (5,6))

C = A + B

print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("Result (A+B):\n", C)
# Out:
# Matrix A:
#  [[3 6 7 7 1 4]
#  [1 2 2 1 4 8]
#  [6 3 7 6 9 8]
#  [2 2 3 7 4 9]
#  [5 9 3 8 9 4]]
# Matrix B:
#  [[9 8 4 5 7 6]
#  [5 2 4 2 9 8]
#  [9 2 2 5 7 6]
#  [7 8 3 4 4 4]
#  [8 6 2 1 3 2]]
# Result (A+B):
#  [[12 14 11 12  8 10]
#  [ 6  4  6  3 13 16]
#  [15  5  9 11 16 14]
#  [ 9 10  6 11  8 13]
#  [13 15  5  9 12  6]]

# %%
A = np.random.randint(1, 10, (2,3))
B = np.random.randint(1, 10, (2,3))
C = np.random.randint(1, 10, (2,3))

result = (A - B) + C

print(A, B, C, result)

# %%
A = np.random.randint(1, 21, (4,4))
print(A)

num = int(input("Enter number: "))

count = np.count_nonzero(A == num)

if count > 0:
    print("Found", count, "times")
else:
    print("Not found")
# Out:
# [[ 1 13  8  9]
#  [10  8 19  7]
#  [ 3  8 16 11]
#  [13 11 18 16]]

# %%
A = np.random.randint(1,10,(5,5))

rank = np.linalg.matrix_rank(A)
det = np.linalg.det(A)

print("Rank:", rank)
print("Determinant:", det)

# %%
A = np.random.randint(1,10,(5,5))
x = np.random.randint(1,10,(5,1))

b = np.dot(A, x)

solution = np.linalg.solve(A, b)

print(solution)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([-3,-2,-1,0,1,2,3,4,5,7])
y = np.array([-7.6,1,4.8,5,2.8,-0.6,-4,-6.2,-6,6.4])

coeff = np.polyfit(x, y, 3)

print("Polynomial coefficients:", coeff)

p = np.poly1d(coeff)
xp = np.linspace(-3,7,100)

plt.scatter(x,y)
plt.plot(xp, p(xp))
plt.show()
# Out:
# Polynomial coefficients: [ 0.2 -1.2 -1.2  5. ]
